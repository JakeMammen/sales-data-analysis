# %% [markdown]
# ### Sales Data Analysis Project

# %%
pip install pandas numpy matplotlib seaborn pandasql -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandasql as ps  # For SQL queries

# %%
df = pd.read_csv(
    '/Users/jakemammen/Developer/sales-data-analysis/Superstore.csv',
    encoding='latin1'
)

# %%
print(df.shape)
# Out:
# (9994, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 1       2  CA-2013-152156  09-11-2013  12-11-2013    Second Class    CG-12520
# 2       3  CA-2013-138688  13-06-2013  17-06-2013    Second Class    DV-13045
# 3       4  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
# 4       5  US-2012-108966  11-10-2012  18-10-2012  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)

# %%
df.fillna(0)
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2013-152156 2013-11-09  12-11-2013    Second Class
# 1          2  CA-2013-152156 2013-11-09  12-11-2013    Second Class
# 2          3  CA-2013-138688 2013-06-13  17-06-2013    Second Class
# 3          4  US-2012-108966 2012-10-11  18-10-2012  Standard Class
# 4          5  US-2012-108966 2012-10-11  18-10-2012  Standard Class
# ...      ...             ...        ...         ...             ...
# 9989    9990  CA-2011-110422 2011-01-22  24-01-2011    Second Class
# 9990    9991  CA-2014-121258 2014-02-27  04-03-2014  Standard Class
# 9991    9992  CA-2014-121258 2014-02-27  04-03-2014  Standard Class
# 9992    9993  CA-2014-121258 2014-02-27  04-03-2014  Standard Class
# 9993    9994  CA-2014-119914 2014-05-05  10-05-2014    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df = df.drop_duplicates()

# %%
sns.boxplot(df['Sales'])
# Out:
# <Axes: ylabel='Sales'>

# %%
df['Sales'] = np.clip(df['Sales'], 0, df['Sales'].quantile(0.99))

# %%
df['Profit Margin'] = df['Profit'] / df['Sales'] * 100

# %%
df['Year'] = df['Order Date'].dt.year

# %%
df['Month'] = df['Order Date'].dt.month

# %%
query = """
SELECT Region, SUM(Sales) AS Total_Sales
FROM df
GROUP BY Region
ORDER BY Total_Sales DESC
"""
regional_sales = ps.sqldf(query, locals())

# %%
df['Sales'].sum()
# Out:
# np.float64(2092334.1702999994)

# %%
df.groupby('Category')['Sales'].mean()
# Out:
# Category
# Furniture          341.537276
# Office Supplies    111.198227
# Technology         377.830585
# Name: Sales, dtype: float64

# %%
regional_sales
# Out:
#     Region  Total_Sales
# 0     West  683845.4601
# 1     East  609198.9164
# 2  Central  452921.4656
# 3    South  346368.3282

# %%
monthly_sales = df.groupby(['Year', 'Month'])['Sales'].sum().reset_index()

# %%
monthly_sales
# Out:
#     Year  Month       Sales
# 0   2011      1  13854.1036
# 1   2011      2   4810.5580
# 2   2011      3  34515.9882
# 3   2011      4  26612.9896
# 4   2011      5  23414.0516
# 5   2011      6  33810.4462
# 6   2011      7  28240.4376
# 7   2011      8  27909.4685
# 8   2011      9  66749.1340
# 9   2011     10  31199.1356
# 10  2011     11  73072.5351
# 11  2011     12  63572.0563
# 12  2012      1  16035.9008
# 13  2012      2  12150.5816
# 14  2012      3  33013.3198
# 15  2012      4  32863.9331
# 16  2012      5  29235.6663
# 17  2012      6  24228.6106
# 18  2012      7  28765.3250
# 19  2012      8  35981.7614
# 20  2012      9  62247.1732
# 21  2012     10  31404.9235
# 22  2012     11  71604.1999
# 23  2012     12  72239.4430
# 24  2013      1  18542.4910
# 25  2013      2  16599.4556
# 26  2013      3  42335.5860
# 27  2013      4  32630.3576
# 28  2013      5  48231.3348
# 29  2013      6  36893.1042
# 30  2013      7  38122.4896
# 31  2013      8  32860.2029
# ...

# %%
sns.barplot(x='Category', y='Sales', data=df.groupby('Category')['Sales'].sum().reset_index())
plt.title('Total Sales by Category')
plt.savefig('total_sales_by_category.png')
plt.show()

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.lineplot(x='Month', y='Sales', hue='Year', data=monthly_sales)
plt.title('Monthly Sales Trend')
plt.savefig('monthly_sales_trend.png')
plt.show()

# %% [markdown]
# Test
